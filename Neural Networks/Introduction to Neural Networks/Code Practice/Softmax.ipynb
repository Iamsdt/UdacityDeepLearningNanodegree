# %%
import numpy as np

def softmax(x):
    ex = np.exp(x)
    s = np.sum(np.exp(x))
    return ex/s

# %%
arr = np.array([1, 2, 0, 2, 1, 4])
softmax(arr)
# Out:
# array([0.03585517, 0.09746446, 0.01319038, 0.09746446, 0.03585517,
#        0.72017036])
